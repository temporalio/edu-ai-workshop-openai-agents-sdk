# %% [markdown]
# # Exercise 3.1: Demonstrating Durability — Solution

# %% [markdown]
# ## Setup
#
# Before doing the exercise, you need to:
#
# - Install necessary dependencies
# - Create your `.env` file and supply your API key
# - Load the environment variables
# - Download and start a local Temporal Service

# %%
# %pip install --quiet temporalio openai-agents httpx nest-asyncio pytz

# Import all required modules
import asyncio
import httpx
from datetime import timedelta, datetime
import pytz
from temporalio import activity, workflow
from temporalio.client import Client
from temporalio.worker import Worker
from temporalio.contrib import openai_agents
from temporalio.contrib.openai_agents import OpenAIAgentsPlugin, ModelActivityParameters
from temporalio.worker.workflow_sandbox import SandboxedWorkflowRunner, SandboxRestrictions
from agents import Agent, Runner

print("✅ All imports successful")
# Out:
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ✅ All imports successful

# %% [markdown]
# ## Component 1: `activities.py`
#
# Define the weather activity that fetches alerts from the National Weather Service API.
#
# **Key points:**
# - Returns a `dict` (not formatted string) so the LLM can interpret the data
# - Activity name explicitly set with `@activity.defn(name="get_weather")`
# - Simple error handling - just `raise_for_status()` and let Temporal retry
# - No console logging or attempt tracking needed

# %%
from temporalio.exceptions import ApplicationError

@activity.defn(name="get_weather")  # Register this function as a Temporal activity
async def get_weather_error(state: str) -> dict:  # Accept 2-letter state code, return structured data
    """Fetch active NWS alerts for a 2-letter US state code w/ error (e.g., 'CA')."""
    # This simulates a temporary failure - maybe a database is down,
    # or an API is temporarily unavailable
    raise ApplicationError("Simulated failure: Summary service temporarily unavailable")

print("✅ Activity 'get_weather' defined")
# Out:
# ✅ Activity 'get_weather' defined

# %%
# Define which task queue this workflow will use for communication
TASK_QUEUE = "agents-sdk-error"

@workflow.defn(sandboxed=False)  # Disable sandbox for Jupyter compatibility
class ErrorWorkflow:  # Define workflow class for orchestrating the agent
    @workflow.run  # Mark this method as the workflow entry point
    async def run(self, user_query: str) -> str:  # Accept user query, return agent response
        # Create the Agent inside the workflow with tools and instructions
        agent = Agent(
            name="Weather Assistant",  # Name shown in OpenAI traces
            # Define agent's role and behavior when handling user queries
            instructions=(
                "You are a helpful assistant that explains current weather alerts for U.S. states. "
                "When the user asks about alerts, call the get_weather tool, then summarize results."
            ),
            # Provide list of tools the agent can use
            tools=[
                # Convert Temporal activity to Agent tool for durable execution
                openai_agents.workflow.activity_as_tool(
                    # Update the activity function to the error version
                    get_weather_error,
                    start_to_close_timeout=timedelta(seconds=10),  # Max time for activity execution
                )
            ],
        )
        
        # Run the agent with user query - tool calls execute as Temporal activities
        result = await Runner().run(agent, user_query)
        
        # Safely extract final output from result object (handles different result types)
        return getattr(result, "final_output", str(result))

print(f"✅ Workflow 'ErrorWorkflow' defined (task queue: {TASK_QUEUE})")
# Out:
# ✅ Workflow 'ErrorWorkflow' defined (task queue: agents-sdk-error)

# %% [markdown]
# ## Component 3: `worker.py`
#
# Run the worker that polls for and executes workflow/activity tasks.
#
# **Key points:**
# - Connects to Temporal with `OpenAIAgentsPlugin` (required)
# - Configures `ModelActivityParameters` for AI model timeout settings
# - Uses `SandboxedWorkflowRunner` with passthrough for `httpx`
# - Runs in background as an async task in Jupyter

# %%
async def run_worker():  # Define async function to start and run the worker
    """Start a Temporal worker that listens for workflow and activity tasks."""
    # Connect to local Temporal server with OpenAI Agents SDK plugin
    client = await Client.connect(
        "localhost:7233",  # Temporal server address
        # Register plugins to extend Temporal's functionality
        plugins=[
            # Plugin that enables OpenAI Agents SDK integration with Temporal
            OpenAIAgentsPlugin(
                # Configure timeout settings for AI model inference activities
                model_params=ModelActivityParameters(
                    start_to_close_timeout=timedelta(seconds=30)  # Max time for LLM calls
                )
            )
        ],
    )

    # Create worker that polls the task queue for work
    worker = Worker(
        client,  # Use the connected Temporal client
        task_queue=TASK_QUEUE,  # Which queue to poll for tasks
        # Udpate to the ErrorWorkflow
        workflows=[ErrorWorkflow],
        # Use the activity that has an intentional error
        activities=[get_weather_error],  # List of activities this worker can execute
    )
    
    print(f"✅ Worker started on task queue: {TASK_QUEUE}")
    print("   Listening for workflow and activity tasks...")
    # Start polling and executing tasks (blocks until stopped)
    await worker.run()

# Apply nest_asyncio to allow nested event loops in Jupyter
import nest_asyncio

nest_asyncio.apply()
# Create background task to run worker without blocking the notebook
worker_task = asyncio.create_task(run_worker())
print("🔄 Worker running in background")
# Out:
# 🔄 Worker running in background
# ✅ Worker started on task queue: agents-sdk-error
#    Listening for workflow and activity tasks...
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 1, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 2, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 3, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 4, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 5, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 6, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 7, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 8, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 9, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 10, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 11, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 12, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 13, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 14, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 15, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 16, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 17, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 18, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 19, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 20, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 21, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 22, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 23, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 24, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 25, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 26, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 27, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 28, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 29, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 30, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 31, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# ...
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 83, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 84, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 85, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 86, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 87, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 88, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 89, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 90, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 91, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable
# Completing activity as failed ({'activity_id': '2', 'activity_type': 'get_weather', 'attempt': 92, 'namespace': 'default', 'task_queue': 'agents-sdk-error', 'workflow_id': 'weather-wed-oct-22-121217est', 'workflow_run_id': '019a0cb1-4c7a-7080-9ea8-c07d5366fc32', 'workflow_type': 'ErrorWorkflow'})
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 297, in _handle_start_activity_task
#     result = await self._execute_activity(start, running_activity, task_token)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 610, in _execute_activity
#     return await impl.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/contrib/openai_agents/_trace_interceptor.py", line 284, in execute_activity
#     return await self.next.execute_activity(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.11/site-packages/temporalio/worker/_activity.py", line 805, in execute_activity
#     return await input.fn(*input.args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19956/634155942.py", line 8, in get_weather_error
#     raise ApplicationError("Simulated failure: Summary service temporarily unavailable")
# temporalio.exceptions.ApplicationError: Simulated failure: Summary service temporarily unavailable

# %% [markdown]
# ## Component 4: `starter.py`
#
# Running a Temporal Workflow.
#
# ### Executing the Workflow
# * Temporal Workflows are executed indirectly
# * Request execution from the Temporal Service
# * You do this with the Temporal Client

# %%
async def run_solution():  # Define async function to execute the workflow
    """Execute the weather agent workflow."""
    # Define the user query to send to the agent
    query = "What weather alerts are active in CA?"
    
    # Generate workflow ID with EST timestamp for human-readable tracking
    est = pytz.timezone('US/Eastern')  # Create EST timezone object
    now = datetime.now(est)  # Get current time in EST
    # Format timestamp as readable string with day-month-date-time pattern
    workflow_id = f"error-{now.strftime('%a-%b-%d-%I%M%S').lower()}est"
    
    # Connect to Temporal server with OpenAI Agents SDK plugin
    client = await Client.connect(
        "localhost:7233",  # Temporal server address
        plugins=[OpenAIAgentsPlugin()]  # Enable OpenAI Agents integration
    )
    
    print(f"🚀 Starting workflow: {workflow_id}")
    print(f"📝 Query: {query}\n")
    
    # Start the workflow (non-blocking) and get handle for tracking
    handle = await client.start_workflow(
        ErrorWorkflow.run,  # Update to the ErrorWorkflow
        query,  # User query parameter passed to workflow
        id=workflow_id,  # Unique workflow ID for tracking in Temporal UI
        task_queue=TASK_QUEUE  # Queue where worker will pick up this workflow
    )
    
    print(f"✅ Workflow started: {handle.id}")
    # Print Temporal UI link for observing workflow execution
    print(f"🔗 View in Temporal UI: http://localhost:8233/namespaces/default/workflows/{workflow_id}\n")
    print("⏳ Waiting for agent response...\n")
    
    # Wait for workflow to complete and get result (blocking)
    result = await handle.result()
    
    print("=" * 60)
    print("🤖 Agent Response:")
    print("=" * 60)
    print(result)
    print("=" * 60)

# Run the solution with Jupyter-specific async handling
try:
    # Try to get existing event loop (Jupyter has one running)
    loop = asyncio.get_running_loop()
    # Execute in existing loop
    await run_solution()
except RuntimeError:
    # If no loop exists, create new one and run
    asyncio.run(run_solution())
# Out:
# 🚀 Starting workflow: weather-wed-oct-22-121217est
# 📝 Query: What weather alerts are active in CA?
#
# ✅ Workflow started: weather-wed-oct-22-121217est
# 🔗 View in Temporal UI: http://localhost:8233/namespaces/default/workflows/weather-wed-oct-22-121217est
#
# ⏳ Waiting for agent response...
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[6], line 48
#      46     loop = asyncio.get_running_loop()
#      47     # Execute in existing loop
# ---> 48     await run_solution()
#      49 except RuntimeError:
#      50     # If no loop exists, create new one and run
#      51     asyncio.run(run_solution())
#
# Cell In[6], line 35, in run_solution()
#      32 print("⏳ Waiting for agent response...\n")
#      34 # Wait for workflow to complete and get result (blocking)
# ---> 35 result = await handle.result()
#      37 print("=" * 60)
#      38 print("🤖 Agent Response:")
#
# File ~/.local/lib/python3.11/site-packages/temporalio/client.py:1688, in WorkflowHandle.result(self, follow_runs, rpc_metadata, rpc_timeout)
#    1686 hist_run_id = self._result_run_id
#    1687 while True:
# -> 1688     async for event in self._fetch_history_events_for_run(
#    1689         hist_run_id,
#    1690         wait_new_event=True,
#    1691         event_filter_type=WorkflowHistoryEventFilterType.CLOSE_EVENT,
#    1692         skip_archival=True,
#    1693         rpc_metadata=rpc_metadata,
#    1694         rpc_timeout=rpc_timeout,
#    1695     ):
#    1696         if event.HasField("workflow_execution_completed_event_attributes"):
#    1697             complete_attr = event.workflow_execution_completed_event_attributes
#
# File ~/.local/lib/python3.11/site-packages/temporalio/client.py:3409, in WorkflowHistoryEventAsyncIterator.__anext__(self)
#    3405 if self._current_page_index >= len(self._current_page):
#    3406     # If there is a next page token, try to get another page and try
#    3407     # again
#    3408     if self._next_page_token is not None:
# -> 3409         await self.fetch_next_page()
#    3410         continue
#    3411     # No more pages means we're done
#
# File ~/.local/lib/python3.11/site-packages/temporalio/client.py:3366, in WorkflowHistoryEventAsyncIterator.fetch_next_page(self, page_size)
#    3359 async def fetch_next_page(self, *, page_size: Optional[int] = None) -> None:
#    3360     """Fetch the next page if any.
#    3361
#    3362     Args:
#    3363         page_size: Override the page size this iterator was originally
#    3364             created with.
#    3365     """
# -> 3366     resp = await self._client.workflow_service.get_workflow_execution_history(
#    3367         temporalio.api.workflowservice.v1.GetWorkflowExecutionHistoryRequest(
#    3368             namespace=self._client.namespace,
#    3369             execution=temporalio.api.common.v1.WorkflowExecution(
#    3370                 workflow_id=self._input.id,
#    3371                 run_id=self._input.run_id or "",
#    3372             ),
#    3373             maximum_page_size=self._input.page_size or 0,
#    3374             next_page_token=self._next_page_token or b"",
#    3375             wait_new_event=self._input.wait_new_event,
#    3376             history_event_filter_type=temporalio.api.enums.v1.HistoryEventFilterType.ValueType(
#    3377                 self._input.event_filter_type
#    3378             ),
#    3379             skip_archival=self._input.skip_archival,
#    3380         ),
#    3381         retry=True,
#    3382         metadata=self._input.rpc_metadata,
#    3383         timeout=self._input.rpc_timeout,
#    3384     )
#    3385     # We don't support raw history
#    3386     assert len(resp.raw_history) == 0
#
# File ~/.local/lib/python3.11/site-packages/temporalio/service.py:1278, in ServiceCall.__call__(self, req, retry, metadata, timeout)
#    1255 async def __call__(
#    1256     self,
#    1257     req: ServiceRequest,
#    (...)   1261     timeout: Optional[timedelta] = None,
#    1262 ) -> ServiceResponse:
#    1263     """Invoke underlying client with the given request.
#    1264
#    1265     Args:
#    (...)   1276         RPCError: Any RPC error that occurs during the call.
#    1277     """
# -> 1278     return await self.service_client._rpc_call(
#    1279         self.name,
#    1280         req,
#    1281         self.resp_type,
#    1282         service=self.service,
#    1283         retry=retry,
#    1284         metadata=metadata,
#    1285         timeout=timeout,
#    1286     )
#
# File ~/.local/lib/python3.11/site-packages/temporalio/service.py:1351, in _BridgeServiceClient._rpc_call(self, rpc, req, resp_type, service, retry, metadata, timeout)
#    1349 try:
#    1350     client = await self._connected_client()
# -> 1351     resp = await client.call(
#    1352         service=service,
#    1353         rpc=rpc,
#    1354         req=req,
#    1355         resp_type=resp_type,
#    1356         retry=retry,
#    1357         metadata=metadata,
#    1358         timeout=timeout,
#    1359     )
#    1360     if LOG_PROTOS:
#    1361         logger.debug("Service %s response from %s: %s", service, rpc, resp)
#
# File ~/.local/lib/python3.11/site-packages/temporalio/bridge/client.py:151, in Client.call(self, service, rpc, req, resp_type, retry, metadata, timeout)
#     149 # Convert response
#     150 resp = resp_type()
# --> 151 resp.ParseFromString(await resp_fut)
#     152 return resp
#
# File /usr/local/lib/python3.11/asyncio/futures.py:287, in Future.__await__(self)
#     285 if not self.done():
#     286     self._asyncio_future_blocking = True
# --> 287     yield self  # This tells Task to wait for completion.
#     288 if not self.done():
#     289     raise RuntimeError("await wasn't used with future")
#
# File /usr/local/lib/python3.11/asyncio/tasks.py:349, in Task.__wakeup(self, future)
#     347 def __wakeup(self, future):
#     348     try:
# --> 349         future.result()
#     350     except BaseException as exc:
#     351         # This may also be a cancellation.
#     352         self.__step(exc)
#
# File /usr/local/lib/python3.11/asyncio/futures.py:198, in Future.result(self)
#     196 if self._state == _CANCELLED:
#     197     exc = self._make_cancelled_error()
# --> 198     raise exc
#     199 if self._state != _FINISHED:
#     200     raise exceptions.InvalidStateError('Result is not ready.')
#
# CancelledError:
