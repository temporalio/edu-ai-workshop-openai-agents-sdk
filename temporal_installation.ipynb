# %% [markdown]
# # ⚡ Temporal CLI Installation & Setup
#
# Welcome! 👋 This notebook will help you install and start the Temporal dev server.
#
# **What you'll do:**
# 1. 📥 Install the Temporal CLI
# 2. 🚀 Start the Temporal dev server
# 3. ✅ Verify everything is working
#
# **Run each cell below in order!** ⬇️

# %% [markdown]
# ## Step 1: Install Temporal CLI 📥
#
# This will download and install the Temporal CLI to `~/.temporalio/bin/`
#
# **Expected output:** Installation progress and success message ✅

# %%
# Install Temporal CLI
# !curl -sSf https://temporal.download/cli.sh | sh

# %% [markdown]
# ## Step 2: Start Temporal Dev Server 🚀
#
# This will start the Temporal development server on your local machine.
#
# **Important notes:**
# - 📍 The server runs on ports **7233** (gRPC) and **8233** (Web UI)
# - ⏱️ This cell will keep running - that's normal! The server needs to stay active.
# - 🌐 Access the Temporal Web UI at: http://localhost:8233
# - 🛑 To stop the server, use the stop button in the notebook toolbar or press Ctrl+C
#
# **After running this cell, open a new terminal to run the exercises!** 🎯

# %%
# Start Temporal dev server
!~/.temporalio/bin/temporal server start-dev

# %% [markdown]
# ## Step 3: Verify Installation ✅
#
# After the server starts (you'll see "temporal server start-dev" output above), verify it's working:
#
# 1. 🌐 Open http://localhost:8233 in your browser
# 2. 👀 You should see the Temporal Web UI
# 3. 🎉 Success! You're ready to start the exercises!
#
# ### Next Steps:
#
# - 📓 Start with Exercise 1: `exercises/01_agent_hello_world/exercise.ipynb`
# - 📚 Or jump to any exercise in the `exercises/` directory
# - 🔍 Use the Temporal Web UI to observe your workflows
#
# **Pro tip:** Keep this notebook running while you work on the exercises! 💡
