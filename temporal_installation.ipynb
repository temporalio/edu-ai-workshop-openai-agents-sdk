# %% [markdown]
# # Temporal CLI Installation
#
# This notebook will help you install the Temporal CLI and start the Temporal dev server.
#
# ## Kernel Selection
#
# When you open this notebook, VS Code may prompt you to select a kernel. Choose:
# - **Python 3.11**
# - The kernel name should appear in the top-right corner of the notebook
#
# ![Select Python 3.11 kernel](images/select-kernel.png)
#
# ## Instructions
#
# 1. **Run Cell 1** to install the Temporal CLI (takes ~30 seconds)
# 2. **Run Cell 2** to start the Temporal dev server
#    - This cell will continue running - that's expected! ✅
#    - The server must stay running for exercises 2, 3, and 4
# 3. **Verify** the server is running:
#    - In Codespaces: Go to the **Ports** tab → Find port **8233** → Click the **Globe icon**
#
# Run the cells below in order:

# %% [markdown]
# ## Step 1: Install Temporal CLI
#
# Run the cell below to download and install the Temporal CLI. This may take 20-30 seconds.

# %%
# Install Temporal CLI
# | label: temporal-cli-install
# !curl -sSf https://temporal.download/cli.sh | sh

# %% [markdown]
# ## Step 2: Start Temporal Dev Server
#
# Run the cell below to start the Temporal dev server.
#
# **Important:**
# - This cell will keep running (showing server logs) - this is normal! ✅
# - Do not stop this cell - the server needs to stay running
# - Open a new notebook/terminal to run your exercises
#
# **Verify Temporal is working:**
# ![Open Temporal UI](images/open-ui.png)
# - **In Codespaces:** Go to the **Ports** tab at the bottom → Find port **8233** → Click the **Globe icon**  to view the Temporal UI
# - Or you can click the link in the Output below the cell

# %%
# Start Temporal dev server
#| label: temporal-start
!~/.temporalio/bin/temporal server start-dev
